# %%
# Some imports
from IPython.display import display
import matplotlib.pyplot as plt

import covid
covid.config_plot()

# %% [markdown]
# ## Some COVID data
#
# Let's play with COVID.
# Data from [Johns Hopkins University CSSE](https://github.com/CSSEGISandData/COVID-19).

# %%
df = covid.load_covid()
display(df)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 2/26/21                2442     1756     2977      110     504
# 2/27/21                2443     1775     2979      110     506
# 2/28/21                2443     1796     2983      110     508
# 3/1/21                 2444     1816     2987      110     508
# 3/2/21                 2446     1835     2991      110     510
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# ...

# %%
worst = covid.get_worst(df, 15)
df.filter(worst).plot()
plt.show()
